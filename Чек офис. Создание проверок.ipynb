# %%
import requests
import pandas as pd
import json
from datetime import datetime, date, timedelta
import numpy as np
import urllib3
urllib3.disable_warnings()

# %%
api_key = 'CMfbGFrBa27aUssCtxcuCXKgJ1VBR8VLskwomhAWCbV2W429fCw8jcmH9fGv'
url = 'https://rosakhutor.checkoffice.ru/publicapi/v1/inspections'
headers = {'API-Key': api_key,
           'accept': 'application/json',
           'charset': 'utf-8'}

def set_screening(user_id):
    print(F"Назначается {len(combinations)} проверок:")
    print("")
    for combo in combinations:
        params = {
            'place_id': combo['place_id'],
            'pattern_id': combo['pattern_id'],
            'assignee_id': user_id,
            'date': date_from,
            'deadline_at': date_to
        }

        try:
            response = requests.post(url, headers=headers, verify=False, params=params)

            if response.status_code == 200:
                print(f"✅ {combo['comment']}")         
            else:
                print(f"❌ {combo['comment']}. Код: {response.status_code}, Ответ: {response.text}")
        except Exception as e:
            print(f"Исключение для {combo['comment']}: {str(e)}")       
    print(F"Назначено {len(combinations)} проверок")
    
elena = 47171
julia = 26732
ivan_alex = 33047
auditor = 22385

# %%
combinations = [
    # Магазины
    {'place_id': 45462, 'pattern_id': 125483, 'comment': 'Магазин | 2320 перед рестораном'},
    {'place_id': 45461, 'pattern_id': 125483, 'comment': 'Магазин | 2320 за стеклом'},
    {'place_id': 45481, 'pattern_id': 125483, 'comment': 'Магазин | Роза приют'},
    {'place_id': 45459, 'pattern_id': 125483, 'comment': 'Магазин | Романов мост'},
    {'place_id': 45456, 'pattern_id': 125483, 'comment': 'Магазин | Музей Археологии'},
    
    # Инфоцентры
    {'place_id': 45481, 'pattern_id': 125434, 'comment': 'Инфоцентр | Роза приют'},
    {'place_id': 45459, 'pattern_id': 125434, 'comment': 'Инфоцентр | Романов мост'},
    
    # Контактные центры
    {'place_id': 45491, 'pattern_id': 125480, 'comment': 'КЦ | Гиды ЦАО'},
    {'place_id': 45463, 'pattern_id': 125480, 'comment': 'КЦ | КЦ'},
    
    # Кассы
    {'place_id': 45481, 'pattern_id': 125467, 'comment': 'Касса | Роза приют'},
    {'place_id': 45391, 'pattern_id': 125467, 'comment': 'Касса | Олимпия'},
    {'place_id': 45399, 'pattern_id': 125467, 'comment': 'Касса | Стрела'},
    {'place_id': 45474, 'pattern_id': 125467, 'comment': 'Касса | Мзымта Двор'},
    {'place_id': 45417, 'pattern_id': 125467, 'comment': 'Касса | Родельбан'},
    {'place_id': 65045, 'pattern_id': 125467, 'comment': 'Касса | Йети парк'},
    {'place_id': 45447, 'pattern_id': 125467, 'comment': 'Касса | Пляж'},
    {'place_id': 45457, 'pattern_id': 125467, 'comment': 'Касса | Моя Россия'},
    
    # Прокаты
    {'place_id': 45481, 'pattern_id': 125547, 'comment': 'Прокат | Роза приют'},
    {'place_id': 45474, 'pattern_id': 125547, 'comment': 'Прокат | Мзымта Двор'},
    
    # Администраторы ЦАО
    {'place_id': 45459, 'pattern_id': 100745, 'comment': 'Администратор ЦАО | Романов мост'},
    
    # Подъемники
    {'place_id': 45391, 'pattern_id': 125818, 'comment': 'Подъемник | Олимпия'},
    {'place_id': 45381, 'pattern_id': 125818, 'comment': 'Подъемник | Заповедный лес'},
    {'place_id': 45385, 'pattern_id': 125818, 'comment': 'Подъемник | Кавказский экспресс'},
    {'place_id': 45375, 'pattern_id': 125818, 'comment': 'Подъемник | Волчья скала'},
    {'place_id': 45405, 'pattern_id': 125818, 'comment': 'Подъемник | Эдельвейс'},
    
    # Активности
    {'place_id': 45417, 'pattern_id': 125800, 'comment': 'Родельбан | Контролер посадчик'},
    {'place_id': 65045, 'pattern_id': 132395, 'comment': 'Инструктор Йети | Йети парк'},
    {'place_id': 45456, 'pattern_id': 125485, 'comment': 'Экскурсовод Муз Арх | Музей Археологии'},
    {'place_id': 45456, 'pattern_id': 135472, 'comment': 'Администратор Муз Арх | Музей Археологии'},
    {'place_id': 45447, 'pattern_id': 125536, 'comment': 'Контролер пляжа | Пляж'},
    {'place_id': 45457, 'pattern_id': 125484, 'comment': 'Экскурсовод МР | Моя Россия'},
    
    # СПИР
    {'place_id': 45454, 'pattern_id': 125817, 'comment': 'СПИР | Роза Ски Инн'},
    {'place_id': 45494, 'pattern_id': 125817, 'comment': 'СПИР | Роза Спрингс'},
    {'place_id': 45451, 'pattern_id': 125817, 'comment': 'СПИР | Роза Шале'},
    {'place_id': 50460, 'pattern_id': 125817, 'comment': 'СПИР | Вальсет Центр'},
    {'place_id': 68449, 'pattern_id': 125817, 'comment': 'СПИР | Вальсет Премиум'},
    {'place_id': 50461, 'pattern_id': 125817, 'comment': 'СПИР | Фристайл'},
    
    # Отдел бронирования
    {'place_id': 45454, 'pattern_id': 125508, 'comment': 'ОБ | Роза Ски Инн'},
    {'place_id': 45494, 'pattern_id': 125508, 'comment': 'ОБ | Роза Спрингс'},
    {'place_id': 45451, 'pattern_id': 125508, 'comment': 'ОБ | Роза Шале'},
    {'place_id': 50460, 'pattern_id': 125508, 'comment': 'ОБ | Вальсет Центр'},
    {'place_id': 50461, 'pattern_id': 125508, 'comment': 'ОБ | Фристайл'},
    
    # Кафе
    {'place_id': 45464, 'pattern_id': 125469, 'comment': 'Кафе | Берлога'},
    {'place_id': 45465, 'pattern_id': 125469, 'comment': 'Кафе | Берлога. Мангальная зона'},
    {'place_id': 45425, 'pattern_id': 125469, 'comment': 'Кафе | Высота. Киоск'},
    {'place_id': 67772, 'pattern_id': 125469, 'comment': 'Кафе | Бриз'},
    {'place_id': 45471, 'pattern_id': 125469, 'comment': 'Кафе | Лес. Кафе'},
    {'place_id': 45470, 'pattern_id': 125469, 'comment': 'Кафе | Лес. Киоск'},
    {'place_id': 65054, 'pattern_id': 125469, 'comment': 'Кафе | Йети кафе'},
    
    # Рестораны
    {'place_id': 45428, 'pattern_id': 125782, 'comment': 'Ресторан | Дичь'},
    {'place_id': 45422, 'pattern_id': 125782, 'comment': 'Ресторан | Варежка'},
    {'place_id': 45427, 'pattern_id': 125782, 'comment': 'Ресторан | Высота'},
    {'place_id': 51167, 'pattern_id': 125782, 'comment': 'Ресторан | Рукола'},
    {'place_id': 67772, 'pattern_id': 125782, 'comment': 'Ресторан | Бриз'},
    
    # Фотограф
    {'place_id': 80246, 'pattern_id': 145199, 'comment': 'Фотограф | Йети на Пике'},
    {'place_id': 80248, 'pattern_id': 145199, 'comment': 'Фотограф | Олимпийские кольца'},
    {'place_id': 80247, 'pattern_id': 145199, 'comment': 'Фотограф | Качели над облаками'},
    {'place_id': 160186, 'pattern_id': 145199, 'comment': 'Фотограф | Качели на 1350'},
    {'place_id': 156528, 'pattern_id': 145199, 'comment': 'Фотограф | Пик 1'},
    {'place_id': 156529, 'pattern_id': 145199, 'comment': 'Фотограф | Пик 2'},
    {'place_id': 88997, 'pattern_id': 145199, 'comment': 'Фотограф | Сердце у Родельбана'},
    
    
    # Касса фотослужбы
    {'place_id': 80246, 'pattern_id': 162017, 'comment': 'Кассир фотозоны | Йети на Пике'},
    {'place_id': 80248, 'pattern_id': 162017, 'comment': 'Кассир фотозоны | Олимпийские кольца'},
    {'place_id': 80247, 'pattern_id': 162017, 'comment': 'Кассир фотозоны | Качели над облаками'},
    {'place_id': 160186, 'pattern_id': 162017, 'comment': 'Кассир фотозоны | Качели на 1350'},
    {'place_id': 45405, 'pattern_id': 162017, 'comment': 'Кассир фотозоны | Эдельвейс'},
    {'place_id': 45375, 'pattern_id': 162017, 'comment': 'Кассир фотозоны | Волчья скала'},
    {'place_id': 156528, 'pattern_id': 162017, 'comment': 'Кассир фотозоны | Пик 1'},
    {'place_id': 156529, 'pattern_id': 162017, 'comment': 'Кассир фотозоны | Пик 2'},
    {'place_id': 88997, 'pattern_id': 162017, 'comment': 'Кассир фотозоны | Сердце у Родельбана'}
]

# %%
len(combinations)
# Out:
# 70

# %%
# elena, julia, ivan_alex, auditor

date_from = '2025-09-24T00:00:00'
date_to   = '2025-09-25T23:00:00'

set_screening(ivan_alex)
# Out:
# Назначается 15 проверок:
#
# ✅ Магазин | Роза приют
# ✅ Магазин | Романов мост
# ✅ Инфоцентр | Романов мост
# ✅ КЦ | КЦ
# ✅ Касса | Родельбан
# ✅ Прокат | Мзымта Двор
# ✅ Родельбан | Контролер посадчик
# ✅ СПИР | Вальсет Центр
# ✅ СПИР | Вальсет Премиум
# ✅ СПИР | Фристайл
# ✅ ОБ | Роза Спрингс
# ✅ ОБ | Фристайл
# ✅ Ресторан | Дичь
# ✅ Ресторан | Варежка
# ✅ Ресторан | Рукола
# Назначено 15 проверок
